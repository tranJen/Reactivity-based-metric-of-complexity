# %%
import pandas as pd
import numpy as np\
import matplotlib.pyplot as plt

# %%
def count_num_reaction(data):
    '''Count how many reactions there are'''
    rxnCount_data = data['Reaction ID'].nunique()
    print('Number of Reactions:', rxnCount_data)

# %% [markdown]
# ## Define general procedure to test

# %%
# note this is data that hasnt not been verified
data_in_Ring = pd.read_excel('/Users/suongsuong/Documents/GitHub/Reactivity-based-metric-of-complexity/Reduction of ketone/ketone_in_ring(no_manualcheck).xlsx')
data_in_Chain = pd.read_excel('/Users/suongsuong/Documents/GitHub/Reactivity-based-metric-of-complexity/Reduction of ketone/ketone_in_chain(no_manualcheck).xlsx')

# %%
data = pd.concat([data_in_Ring,data_in_Chain], ignore_index= True)

# %%
count_num_reaction(data)
# Out:
# Number of Reactions: 1396

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Time (Reaction Details) [h]'], bins=70, color='cornflowerblue', edgecolor='black')
plt.xlabel('Time')
plt.xticks(np.arange(0, 25, step=1))
plt.ylabel('Count')

# Customize 
ax = plt.gca()  
ax.spines[['top', 'bottom', 'left', 'right']].set_visible(False)
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad=5)
ax.yaxis.set_tick_params(pad=10)
ax.grid(visible=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()

print('Statistic of Time:')
data['Time (Reaction Details) [h]'].describe()
# Out:
# Statistic of Time:
# count    1396.000000
# mean        1.306982
# std         1.558489
# min         0.016667
# 25%         0.500000
# 50%         1.000000
# 75%         2.000000
# max        20.000000
# Name: Time (Reaction Details) [h], dtype: float64
